# %%
import sys
import os
from quickfs import QuickFS

# Shut down warnings
import warnings
warnings.filterwarnings("ignore")

# Set API key and project directory
api_key = "***REMOVED***"
invest_proj_dir = r"d:\Coding Projects\Investment Analysis"
save_path = invest_proj_dir

os.environ['API_QUICKFS'] = api_key
os.environ['INVEST_PROJ_DIR'] = invest_proj_dir

client = QuickFS(api_key)
sys.path.append(invest_proj_dir)

# %%
#double check that the environment variables are set correctly
print("API Key from ENV:", os.environ.get('API_QUICKFS'))
print("Project Directory from ENV:", os.environ.get('INVEST_PROJ_DIR'))
