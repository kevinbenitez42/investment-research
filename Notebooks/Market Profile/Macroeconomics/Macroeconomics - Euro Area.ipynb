# %%
#Notebook description / Structure

#this notebook is intended to analyze the broader Euro Area economy as a whole and give a sense of the macroeconomic
#headwinds and tailwinds that will affect its asset, credit, currency, and labor markets.

# %%
#TODOS
# 1. GDP and growth composition
# 2. Inflation dynamics across the bloc
# 3. Labor market and domestic demand
# 4. ECB policy, liquidity, and bank credit conditions
# 5. Sovereign yields, spreads, FX, and external balance
# 6. Core versus periphery divergence indicators

# %%
#LOAD: libraries, parameters, functions

economy_name = "Euro Area"
