# %%
#Notebook description / Structure

#this notebook is intended to analyze the broader Saudi Arabia economy as a whole and give a sense of the macroeconomic
#headwinds and tailwinds that will affect its asset, credit, currency, and labor markets.

# %%
#TODOS
# 1. GDP and growth composition
# 2. Inflation dynamics
# 3. Labor market and domestic demand
# 4. Policy rates, liquidity, and credit conditions
# 5. Sovereign yields, FX regime, and external balance
# 6. Oil, fiscal, and government-spending cycle indicators

# %%
#LOAD: libraries, parameters, functions

economy_name = "Saudi Arabia"
