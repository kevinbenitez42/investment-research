# %% [markdown]
# # Portfolio Monitoring, Performance & Risk
#
# This notebook launches the complete interactive portfolio dashboard inline. Implementation code lives in `apps/web/portfolio_dashboard.py`.

# %%
# Run the complete Portfolio Monitoring, Performance & Risk dashboard inline.
from pathlib import Path
import runpy

_project_root = Path.cwd().resolve()
for _candidate in (_project_root, *_project_root.parents):
    if (_candidate / "Quantapp").is_dir() and (_candidate / "apps").is_dir():
        _project_root = _candidate
        break
else:
    raise RuntimeError("Could not locate the Investment Research project root.")

runpy.run_path(
    str(_project_root / "apps" / "web" / "portfolio_dashboard.py"),
    run_name="__main__",
);
