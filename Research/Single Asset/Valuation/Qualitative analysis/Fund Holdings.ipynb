# %% [markdown]
# # 1. Analysis - Fund Holdings

# %% [markdown]
# ## Notebook Summary
#
# This notebook is a workspace for tracking institutional ownership and fund positioning in a single company. It can be used to review major holders, changes in fund ownership, concentration trends, new positions, exited positions, and what those shifts may imply for sentiment, liquidity, or the broader investment thesis.

# %%
# 2. Local Parameters

qualitative_params = {
    "ticker_str": "SOXL",
}

TICKER = qualitative_params["ticker_str"]

qualitative_params

# %% [markdown]
# ## Suggested Sections
#
# - Top institutional holders
# - Recent 13F changes
# - New and exited positions
# - Holder concentration trends
# - Active versus passive ownership
# - Notes and follow-up questions
