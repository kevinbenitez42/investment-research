# %% [markdown]
# # 1. Analysis - Company Filings

# %% [markdown]
# ## Notebook Summary
#
# This notebook is a workspace for reviewing company filings and capturing the qualitative signals that matter for the investment thesis. It can be used to track management commentary, segment disclosures, risk factors, capital allocation updates, and other filing-based changes that may affect valuation.

# %%
# 2. Local Parameters

qualitative_params = {
    "ticker_str": "SOXL",
}

TICKER = qualitative_params["ticker_str"]

qualitative_params

# %% [markdown]
# ## Suggested Sections
#
# - Annual report highlights
# - Quarterly filing updates
# - Risk factor changes
# - Management guidance and tone
# - Capital allocation and share count notes
# - Open questions for follow-up
