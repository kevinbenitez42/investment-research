# %% [markdown]
# # 1. Analysis - Porter 5

# %% [markdown]
# ## Notebook Summary
#
# This notebook is a workspace for evaluating industry attractiveness and competitive pressure using Porter's Five Forces. It can be used to assess the bargaining power of customers and suppliers, the threat of new entrants and substitutes, rivalry within the industry, and how those forces affect margins, growth, and long-term returns.

# %%
# 2. Local Parameters

qualitative_params = {
    "ticker_str": "SOXL",
}

TICKER = qualitative_params["ticker_str"]

qualitative_params

# %% [markdown]
# ## Suggested Sections
#
# - Threat of new entrants
# - Bargaining power of suppliers
# - Bargaining power of buyers
# - Threat of substitutes
# - Competitive rivalry
# - Overall industry attractiveness
# - Notes and follow-up questions
