# %% [markdown]
# # 1. Analysis - Management

# %% [markdown]
# ## Notebook Summary
#
# This notebook is a workspace for assessing management quality and leadership execution for a single company. It can be used to track strategy, incentives, capital allocation discipline, communication quality, operating consistency, and any leadership changes that may affect the investment thesis.

# %%
# 2. Local Parameters

qualitative_params = {
    "ticker_str": "SOXL",
}

TICKER = qualitative_params["ticker_str"]

qualitative_params

# %% [markdown]
# ## Suggested Sections
#
# - Leadership team overview
# - CEO and CFO commentary
# - Capital allocation decisions
# - Incentives and compensation
# - Execution track record
# - Governance notes
# - Open questions for follow-up
