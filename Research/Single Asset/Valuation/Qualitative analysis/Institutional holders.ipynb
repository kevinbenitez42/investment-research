# %% [markdown]
# # 1. Analysis - Institutional Holders

# %% [markdown]
# ## Notebook Summary
#
# This notebook is a workspace for reviewing the institutional holder base for a single company. It can be used to track the largest shareholders, ownership concentration, changes in institutional positioning, investor style mix, and what those patterns may imply for sentiment, liquidity, or the broader investment thesis.

# %%
# 2. Local Parameters

qualitative_params = {
    "ticker_str": "SOXL",
}

TICKER = qualitative_params["ticker_str"]

qualitative_params

# %% [markdown]
# ## Suggested Sections
#
# - Largest institutional holders
# - Ownership concentration
# - Recent holder changes
# - Active versus passive mix
# - Long-term holder base trends
# - Notes and follow-up questions
