# %% [markdown]
# # 1. Analysis - Company Details

# %% [markdown]
# ## Notebook Summary
#
# This notebook is a workspace for capturing core company details that help frame the investment case. It can be used to document the business description, operating segments, geographic footprint, customers, suppliers, reporting structure, and other foundational context that supports the rest of the analysis.

# %%
# 2. Local Parameters

qualitative_params = {
    "ticker_str": "SOXL",
}

TICKER = qualitative_params["ticker_str"]

qualitative_params

# %% [markdown]
# ## Suggested Sections
#
# - Business overview
# - Operating segments
# - Geographic exposure
# - Customer and supplier profile
# - Corporate history and structure
# - Key facts and reference notes
