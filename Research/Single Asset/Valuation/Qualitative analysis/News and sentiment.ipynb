# %% [markdown]
# # 1. Analysis - News and Sentiment

# %% [markdown]
# ## Notebook Summary
#
# This notebook is a workspace for tracking recent company news and the broader sentiment around a single stock. It can be used to capture major headlines, earnings reactions, analyst commentary, market narratives, and sentiment shifts that may influence the investment thesis or near-term valuation.

# %%
# 2. Local Parameters

qualitative_params = {
    "ticker_str": "SOXL",
}

TICKER = qualitative_params["ticker_str"]

qualitative_params

# %% [markdown]
# ## Suggested Sections
#
# - Recent headlines
# - Earnings and guidance reactions
# - Analyst commentary
# - Market narrative and sentiment
# - Social and media signals
# - Follow-up items and open questions
