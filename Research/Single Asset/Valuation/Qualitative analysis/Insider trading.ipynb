# %% [markdown]
# # 1. Analysis - Insider Trading

# %% [markdown]
# ## Notebook Summary
#
# This notebook is a workspace for tracking insider buying and selling activity for a single company. It can be used to review executive and director transactions, ownership changes, transaction patterns, timing around earnings or major events, and what insider activity may imply for confidence, incentives, or risk.

# %%
# 2. Local Parameters

qualitative_params = {
    "ticker_str": "SOXL",
}

TICKER = qualitative_params["ticker_str"]

qualitative_params

# %% [markdown]
# ## Suggested Sections
#
# - Recent insider transactions
# - Executive versus director activity
# - Buy versus sell trends
# - Ownership changes over time
# - Trading around key events
# - Notes and follow-up questions
